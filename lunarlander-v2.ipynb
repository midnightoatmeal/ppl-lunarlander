# %%
# virtual display

from pyvirtualdisplay import Display

virtual_display = Display(visible=0, size=(1400, 900))
virtual_display.start()

# %%
# importing the essential libraries
import gymnasium

from huggingface_sb3 import load_from_hub, package_to_hub
from huggingface_hub import notebook_login

from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.monitor import Monitor

# %%
import gymnasium as gym

env = gym.make("LunarLander-v2")
observation, info = env.reset()

for _ in range(20):
  action = env.action_space.sample()
  print(f"Action taken: {action}")

  observation, reward, terminated, truncated, info = env.step(action)

  if terminated or truncated:
    print("Environment is reset")
    observation, info = env.reset()
env.close()
# Out:
# Action taken: 3
# Action taken: 0
# Action taken: 0
# Action taken: 0
# Action taken: 0
# Action taken: 0
# Action taken: 1
# Action taken: 0
# Action taken: 1
# Action taken: 0
# Action taken: 1
# Action taken: 3
# Action taken: 3
# Action taken: 3
# Action taken: 1
# Action taken: 2
# Action taken: 1
# Action taken: 3
# Action taken: 0
# Action taken: 3

# %%
env = gym.make("LunarLander-v2")
env.reset()
print("____OBSERVATION SPACE____\n")
print(f"Observation space shape: {env.observation_space.shape}")
print(f"Sample observation: {env.observation_space.sample()}")
# Out:
# ____OBSERVATION SPACE____
#
# Observation space shape: (8,)
# Sample observation: [-39.034153   -72.051254     2.0247571    3.4367871    0.3081179
#   -0.7239273    0.80091375   0.55113107]

# %%
print("\n___ACTION SPACE____ \n")
print(f"Action space shape: {env.action_space.n}")
print(f"Action space sample: {env.action_space.sample()}")
# Out:
# ___ACTION SPACE____
#
# Action space shape: 4
# Action space sample: 1

# %%
env = make_vec_env("LunarLander-v2", n_envs=16)

# %%
# create environment

env = gym.make("LunarLander-v2")

# instantiate the agent
model = PPO("MlpPolicy", env, verbose=1)

# train the agent
model.learn(total_timesteps=int(2e5))
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 88.6     |
# |    ep_rew_mean     | -161     |
# | time/              |          |
# |    fps             | 607      |
# |    iterations      | 1        |
# |    time_elapsed    | 3        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 92.8        |
# |    ep_rew_mean          | -191        |
# | time/                   |             |
# |    fps                  | 503         |
# |    iterations           | 2           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.010449717 |
# |    clip_fraction        | 0.0525      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.002839148 |
# |    learning_rate        | 0.0003      |
# |    loss                 | 292         |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00875    |
# |    value_loss           | 1.62e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 91.7         |
# |    ep_rew_mean          | -182         |
# | time/                   |              |
# |    fps                  | 485          |
# |    iterations           | 3            |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.008326855  |
# |    clip_fraction        | 0.0486       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.0030993223 |
# |    learning_rate        | 0.0003       |
# |    loss                 | 851          |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00994     |
# |    value_loss           | 1.64e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 93.1         |
# |    ep_rew_mean          | -188         |
# | time/                   |              |
# |    fps                  | 476          |
# |    iterations           | 4            |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.005494345  |
# |    clip_fraction        | 0.0142       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | -0.009397149 |
# |    learning_rate        | 0.0003       |
# |    loss                 | 523          |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00794     |
# |    value_loss           | 1.16e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 95.5         |
# |    ep_rew_mean          | -182         |
# | time/                   |              |
# |    fps                  | 469          |
# |    iterations           | 5            |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0112321675 |
# |    clip_fraction        | 0.0678       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | -0.023046017 |
# |    learning_rate        | 0.0003       |
# |    loss                 | 582          |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00951     |
# |    value_loss           | 1.42e+03     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 97.9          |
# |    ep_rew_mean          | -165          |
# | time/                   |               |
# |    fps                  | 466           |
# |    iterations           | 6             |
# |    time_elapsed         | 26            |
# |    total_timesteps      | 12288         |
# | train/                  |               |
# |    approx_kl            | 0.0070644724  |
# |    clip_fraction        | 0.0377        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.36         |
# |    explained_variance   | -0.0008832216 |
# |    learning_rate        | 0.0003        |
# |    loss                 | 246           |
# |    n_updates            | 50            |
# |    policy_gradient_loss | -0.00455      |
# |    value_loss           | 556           |
# -------------------------------------------
# --------------------------------------------
# | rollout/                |                |
# |    ep_len_mean          | 101            |
# |    ep_rew_mean          | -150           |
# | time/                   |                |
# |    fps                  | 464            |
# |    iterations           | 7              |
# |    time_elapsed         | 30             |
# |    total_timesteps      | 14336          |
# | train/                  |                |
# |    approx_kl            | 0.012150904    |
# |    clip_fraction        | 0.125          |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -1.33          |
# |    explained_variance   | -0.00050997734 |
# |    learning_rate        | 0.0003         |
# |    loss                 | 88             |
# |    n_updates            | 60             |
# |    policy_gradient_loss | -0.00637       |
# |    value_loss           | 300            |
# --------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 105          |
# |    ep_rew_mean          | -140         |
# | time/                   |              |
# |    fps                  | 463          |
# |    iterations           | 8            |
# |    time_elapsed         | 35           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.011627942  |
# |    clip_fraction        | 0.0281       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 0.0012766123 |
# |    learning_rate        | 0.0003       |
# |    loss                 | 216          |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00366     |
# |    value_loss           | 382          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 111         |
# |    ep_rew_mean          | -136        |
# | time/                   |             |
# |    fps                  | 461         |
# |    iterations           | 9           |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.008439885 |
# |    clip_fraction        | 0.0266      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | 0.027284503 |
# |    learning_rate        | 0.0003      |
# |    loss                 | 258         |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0076     |
# |    value_loss           | 441         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 118         |
# |    ep_rew_mean          | -142        |
# | time/                   |             |
# |    fps                  | 460         |
# |    iterations           | 10          |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.005136352 |
# |    clip_fraction        | 0.00396     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | 0.062102914 |
# |    learning_rate        | 0.0003      |
# |    loss                 | 300         |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00404    |
# |    value_loss           | 533         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 123          |
# |    ep_rew_mean          | -144         |
# | time/                   |              |
# |    fps                  | 460          |
# |    iterations           | 11           |
# |    time_elapsed         | 48           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0041080397 |
# |    clip_fraction        | 0.0083       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.25        |
# |    explained_variance   | 0.10899484   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 255          |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00354     |
# |    value_loss           | 558          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 130          |
# |    ep_rew_mean          | -154         |
# | time/                   |              |
# |    fps                  | 459          |
# |    iterations           | 12           |
# |    time_elapsed         | 53           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0062825894 |
# |    clip_fraction        | 0.0131       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.21        |
# |    explained_variance   | 0.1032691    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 186          |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00472     |
# |    value_loss           | 398          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 139          |
# |    ep_rew_mean          | -151         |
# | time/                   |              |
# |    fps                  | 459          |
# |    iterations           | 13           |
# |    time_elapsed         | 57           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0069617815 |
# |    clip_fraction        | 0.0265       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.17        |
# |    explained_variance   | 0.14631999   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 158          |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.0054      |
# |    value_loss           | 416          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 153         |
# |    ep_rew_mean          | -151        |
# | time/                   |             |
# |    fps                  | 458         |
# |    iterations           | 14          |
# |    time_elapsed         | 62          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.006928051 |
# |    clip_fraction        | 0.0989      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.13       |
# |    explained_variance   | 0.24540615  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 67.5        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00958    |
# |    value_loss           | 148         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 160        |
# |    ep_rew_mean          | -146       |
# | time/                   |            |
# |    fps                  | 458        |
# |    iterations           | 15         |
# |    time_elapsed         | 66         |
# |    total_timesteps      | 30720      |
# | train/                  |            |
# |    approx_kl            | 0.00875601 |
# |    clip_fraction        | 0.0738     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.2       |
# |    explained_variance   | 0.16872853 |
# |    learning_rate        | 0.0003     |
# |    loss                 | 82.7       |
# |    n_updates            | 140        |
# |    policy_gradient_loss | -0.00898   |
# |    value_loss           | 234        |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 172          |
# |    ep_rew_mean          | -143         |
# | time/                   |              |
# |    fps                  | 458          |
# |    iterations           | 16           |
# |    time_elapsed         | 71           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0076842913 |
# |    clip_fraction        | 0.0424       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.12        |
# |    explained_variance   | 0.1354698    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 142          |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00855     |
# |    value_loss           | 344          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 179         |
# |    ep_rew_mean          | -141        |
# | time/                   |             |
# |    fps                  | 458         |
# |    iterations           | 17          |
# |    time_elapsed         | 75          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.007167235 |
# |    clip_fraction        | 0.0387      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.16       |
# |    explained_variance   | 0.37463164  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 73.9        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00693    |
# |    value_loss           | 201         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 194        |
# |    ep_rew_mean          | -135       |
# | time/                   |            |
# |    fps                  | 458        |
# |    iterations           | 18         |
# |    time_elapsed         | 80         |
# |    total_timesteps      | 36864      |
# | train/                  |            |
# |    approx_kl            | 0.00702268 |
# |    clip_fraction        | 0.0484     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.16      |
# |    explained_variance   | 0.41577226 |
# |    learning_rate        | 0.0003     |
# |    loss                 | 88         |
# |    n_updates            | 170        |
# |    policy_gradient_loss | -0.00511   |
# |    value_loss           | 217        |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 206          |
# |    ep_rew_mean          | -129         |
# | time/                   |              |
# |    fps                  | 458          |
# |    iterations           | 19           |
# |    time_elapsed         | 84           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0067325127 |
# |    clip_fraction        | 0.0405       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | 0.28500694   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 132          |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00675     |
# |    value_loss           | 234          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 224          |
# |    ep_rew_mean          | -121         |
# | time/                   |              |
# |    fps                  | 458          |
# |    iterations           | 20           |
# |    time_elapsed         | 89           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0090487655 |
# |    clip_fraction        | 0.0909       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.21        |
# |    explained_variance   | 0.617295     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 26.7         |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00985     |
# |    value_loss           | 69.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 240         |
# |    ep_rew_mean          | -111        |
# | time/                   |             |
# |    fps                  | 457         |
# |    iterations           | 21          |
# |    time_elapsed         | 93          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.009873949 |
# |    clip_fraction        | 0.0932      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.18       |
# |    explained_variance   | 0.44253498  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 73.5        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0106     |
# |    value_loss           | 138         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 256         |
# |    ep_rew_mean          | -104        |
# | time/                   |             |
# |    fps                  | 457         |
# |    iterations           | 22          |
# |    time_elapsed         | 98          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.012586085 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.41293103  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 42.6        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0111     |
# |    value_loss           | 96.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 274         |
# |    ep_rew_mean          | -98.1       |
# | time/                   |             |
# |    fps                  | 457         |
# |    iterations           | 23          |
# |    time_elapsed         | 103         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.008660497 |
# |    clip_fraction        | 0.0479      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.16       |
# |    explained_variance   | 0.715786    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 19.1        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00334    |
# |    value_loss           | 57.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 291         |
# |    ep_rew_mean          | -90.3       |
# | time/                   |             |
# |    fps                  | 457         |
# |    iterations           | 24          |
# |    time_elapsed         | 107         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.010669239 |
# |    clip_fraction        | 0.0969      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.12       |
# |    explained_variance   | 0.82801634  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.94        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00605    |
# |    value_loss           | 22.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 310         |
# |    ep_rew_mean          | -83.9       |
# | time/                   |             |
# |    fps                  | 456         |
# |    iterations           | 25          |
# |    time_elapsed         | 112         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.008485281 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.11       |
# |    explained_variance   | 0.66760194  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 36.2        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00856    |
# |    value_loss           | 59.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 324         |
# |    ep_rew_mean          | -78.3       |
# | time/                   |             |
# |    fps                  | 456         |
# |    iterations           | 26          |
# |    time_elapsed         | 116         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.012553053 |
# |    clip_fraction        | 0.144       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 0.66405314  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 33.9        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00804    |
# |    value_loss           | 47.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 341          |
# |    ep_rew_mean          | -75.4        |
# | time/                   |              |
# |    fps                  | 456          |
# |    iterations           | 27           |
# |    time_elapsed         | 121          |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0058165397 |
# |    clip_fraction        | 0.0263       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.03        |
# |    explained_variance   | 0.3699565    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 112          |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.00639     |
# |    value_loss           | 100          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 358         |
# |    ep_rew_mean          | -70.6       |
# | time/                   |             |
# |    fps                  | 456         |
# |    iterations           | 28          |
# |    time_elapsed         | 125         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.010004219 |
# |    clip_fraction        | 0.098       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.868      |
# |    explained_variance   | 0.7610539   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 25.6        |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00674    |
# |    value_loss           | 44.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 375         |
# |    ep_rew_mean          | -70.1       |
# | time/                   |             |
# |    fps                  | 455         |
# |    iterations           | 29          |
# |    time_elapsed         | 130         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.008684719 |
# |    clip_fraction        | 0.099       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.871      |
# |    explained_variance   | 0.7350186   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.8        |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00763    |
# |    value_loss           | 25.5        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 393          |
# |    ep_rew_mean          | -69.1        |
# | time/                   |              |
# |    fps                  | 455          |
# |    iterations           | 30           |
# |    time_elapsed         | 134          |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0061510988 |
# |    clip_fraction        | 0.0407       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.994       |
# |    explained_variance   | 0.32780457   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 15.2         |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00535     |
# |    value_loss           | 48.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 409          |
# |    ep_rew_mean          | -64.2        |
# | time/                   |              |
# |    fps                  | 455          |
# |    iterations           | 31           |
# |    time_elapsed         | 139          |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0064940015 |
# |    clip_fraction        | 0.0507       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.992       |
# |    explained_variance   | 0.05918044   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 13.6         |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.00419     |
# |    value_loss           | 24.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 427         |
# |    ep_rew_mean          | -60.5       |
# | time/                   |             |
# |    fps                  | 456         |
# |    iterations           | 32          |
# |    time_elapsed         | 143         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.009066317 |
# |    clip_fraction        | 0.0854      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.94       |
# |    explained_variance   | 0.27227855  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8           |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00413    |
# |    value_loss           | 17.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 444          |
# |    ep_rew_mean          | -57.7        |
# | time/                   |              |
# |    fps                  | 456          |
# |    iterations           | 33           |
# |    time_elapsed         | 148          |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0056728367 |
# |    clip_fraction        | 0.0571       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.02        |
# |    explained_variance   | 0.22524226   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.71         |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.00538     |
# |    value_loss           | 19.1         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 460         |
# |    ep_rew_mean          | -56.2       |
# | time/                   |             |
# |    fps                  | 456         |
# |    iterations           | 34          |
# |    time_elapsed         | 152         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.008069037 |
# |    clip_fraction        | 0.0708      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 0.49209833  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.91        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.005      |
# |    value_loss           | 9.76        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 477          |
# |    ep_rew_mean          | -51.4        |
# | time/                   |              |
# |    fps                  | 456          |
# |    iterations           | 35           |
# |    time_elapsed         | 156          |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0033159957 |
# |    clip_fraction        | 0.0244       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.961       |
# |    explained_variance   | 0.41827142   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.73         |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00483     |
# |    value_loss           | 17.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 492         |
# |    ep_rew_mean          | -45.9       |
# | time/                   |             |
# |    fps                  | 456         |
# |    iterations           | 36          |
# |    time_elapsed         | 161         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.006059583 |
# |    clip_fraction        | 0.0599      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1          |
# |    explained_variance   | 0.65253305  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.58        |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00457    |
# |    value_loss           | 11.3        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 517          |
# |    ep_rew_mean          | -43.6        |
# | time/                   |              |
# |    fps                  | 456          |
# |    iterations           | 37           |
# |    time_elapsed         | 165          |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0024028376 |
# |    clip_fraction        | 0.00713      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.938       |
# |    explained_variance   | 0.22275656   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 52.2         |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.0023      |
# |    value_loss           | 54.8         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 533          |
# |    ep_rew_mean          | -41.4        |
# | time/                   |              |
# |    fps                  | 456          |
# |    iterations           | 38           |
# |    time_elapsed         | 170          |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0045567527 |
# |    clip_fraction        | 0.041        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.982       |
# |    explained_variance   | 0.1801852    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 35.7         |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00532     |
# |    value_loss           | 61.8         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 548          |
# |    ep_rew_mean          | -38.2        |
# | time/                   |              |
# |    fps                  | 456          |
# |    iterations           | 39           |
# |    time_elapsed         | 174          |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0061784154 |
# |    clip_fraction        | 0.0578       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.951       |
# |    explained_variance   | 0.8497156    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.07         |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.00374     |
# |    value_loss           | 8.97         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 563          |
# |    ep_rew_mean          | -35.8        |
# | time/                   |              |
# |    fps                  | 456          |
# |    iterations           | 40           |
# |    time_elapsed         | 179          |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0062386133 |
# |    clip_fraction        | 0.0323       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.942       |
# |    explained_variance   | 0.45515734   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 22           |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.00257     |
# |    value_loss           | 66.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 577          |
# |    ep_rew_mean          | -34.1        |
# | time/                   |              |
# |    fps                  | 456          |
# |    iterations           | 41           |
# |    time_elapsed         | 183          |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0072188997 |
# |    clip_fraction        | 0.0702       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.968       |
# |    explained_variance   | 0.4810537    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 11.8         |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.00463     |
# |    value_loss           | 13.6         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 598          |
# |    ep_rew_mean          | -28.3        |
# | time/                   |              |
# |    fps                  | 457          |
# |    iterations           | 42           |
# |    time_elapsed         | 188          |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0028573377 |
# |    clip_fraction        | 0.0293       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.886       |
# |    explained_variance   | 0.4417922    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 13           |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00231     |
# |    value_loss           | 107          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 615         |
# |    ep_rew_mean          | -25.2       |
# | time/                   |             |
# |    fps                  | 457         |
# |    iterations           | 43          |
# |    time_elapsed         | 192         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.016923107 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.919      |
# |    explained_variance   | 0.4732188   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 19.6        |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00873    |
# |    value_loss           | 57.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 632         |
# |    ep_rew_mean          | -20.7       |
# | time/                   |             |
# |    fps                  | 456         |
# |    iterations           | 44          |
# |    time_elapsed         | 197         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.008394899 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.932      |
# |    explained_variance   | 0.53962857  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.86        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00544    |
# |    value_loss           | 51.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 648         |
# |    ep_rew_mean          | -15.9       |
# | time/                   |             |
# |    fps                  | 456         |
# |    iterations           | 45          |
# |    time_elapsed         | 201         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.008718185 |
# |    clip_fraction        | 0.127       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.96       |
# |    explained_variance   | 0.8079782   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.05        |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.00636    |
# |    value_loss           | 9.25        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 652         |
# |    ep_rew_mean          | -13.3       |
# | time/                   |             |
# |    fps                  | 456         |
# |    iterations           | 46          |
# |    time_elapsed         | 206         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.018818296 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.902      |
# |    explained_variance   | 0.6383991   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.76        |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00306    |
# |    value_loss           | 14.3        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 671          |
# |    ep_rew_mean          | -5.98        |
# | time/                   |              |
# |    fps                  | 456          |
# |    iterations           | 47           |
# |    time_elapsed         | 210          |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0069153253 |
# |    clip_fraction        | 0.0662       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.785       |
# |    explained_variance   | 0.42667544   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 15.1         |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00418     |
# |    value_loss           | 96.8         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 685        |
# |    ep_rew_mean          | -0.395     |
# | time/                   |            |
# |    fps                  | 456        |
# |    iterations           | 48         |
# |    time_elapsed         | 215        |
# |    total_timesteps      | 98304      |
# | train/                  |            |
# |    approx_kl            | 0.00490616 |
# |    clip_fraction        | 0.0398     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.881     |
# |    explained_variance   | 0.29471695 |
# |    learning_rate        | 0.0003     |
# |    loss                 | 13.5       |
# |    n_updates            | 470        |
# |    policy_gradient_loss | -0.00356   |
# |    value_loss           | 82         |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 702         |
# |    ep_rew_mean          | 0.679       |
# | time/                   |             |
# |    fps                  | 456         |
# |    iterations           | 49          |
# |    time_elapsed         | 219         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.007548808 |
# |    clip_fraction        | 0.0413      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.869      |
# |    explained_variance   | 0.3918994   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.12        |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00254    |
# |    value_loss           | 89.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 719         |
# |    ep_rew_mean          | 3.79        |
# | time/                   |             |
# |    fps                  | 456         |
# |    iterations           | 50          |
# |    time_elapsed         | 224         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.006338679 |
# |    clip_fraction        | 0.0875      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.854      |
# |    explained_variance   | 0.6951411   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.32        |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.00158    |
# |    value_loss           | 9.41        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 737         |
# |    ep_rew_mean          | 6.26        |
# | time/                   |             |
# |    fps                  | 456         |
# |    iterations           | 51          |
# |    time_elapsed         | 228         |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.006590206 |
# |    clip_fraction        | 0.0916      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.928      |
# |    explained_variance   | 0.68516654  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.97        |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.00426    |
# |    value_loss           | 11.5        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 753          |
# |    ep_rew_mean          | 8.04         |
# | time/                   |              |
# |    fps                  | 456          |
# |    iterations           | 52           |
# |    time_elapsed         | 233          |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0040679607 |
# |    clip_fraction        | 0.0379       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.794       |
# |    explained_variance   | 0.39051318   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 114          |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -0.00139     |
# |    value_loss           | 129          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 768         |
# |    ep_rew_mean          | 12          |
# | time/                   |             |
# |    fps                  | 456         |
# |    iterations           | 53          |
# |    time_elapsed         | 237         |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.009959614 |
# |    clip_fraction        | 0.0923      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.864      |
# |    explained_variance   | 0.68421894  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.69        |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.0047     |
# |    value_loss           | 10.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 776         |
# |    ep_rew_mean          | 16.2        |
# | time/                   |             |
# |    fps                  | 456         |
# |    iterations           | 54          |
# |    time_elapsed         | 242         |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.011531465 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.922      |
# |    explained_variance   | 0.43122798  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.68        |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -0.0056     |
# |    value_loss           | 44.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 785         |
# |    ep_rew_mean          | 16.8        |
# | time/                   |             |
# |    fps                  | 456         |
# |    iterations           | 55          |
# ...
# |    ep_len_mean          | 767         |
# |    ep_rew_mean          | 26.1        |
# | time/                   |             |
# |    fps                  | 456         |
# |    iterations           | 81          |
# |    time_elapsed         | 363         |
# |    total_timesteps      | 165888      |
# | train/                  |             |
# |    approx_kl            | 0.005126692 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.802      |
# |    explained_variance   | 0.94873804  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.58        |
# |    n_updates            | 800         |
# |    policy_gradient_loss | -0.00277    |
# |    value_loss           | 8.65        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 764          |
# |    ep_rew_mean          | 24.7         |
# | time/                   |              |
# |    fps                  | 456          |
# |    iterations           | 82           |
# |    time_elapsed         | 368          |
# |    total_timesteps      | 167936       |
# | train/                  |              |
# |    approx_kl            | 0.0075328713 |
# |    clip_fraction        | 0.0607       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.745       |
# |    explained_variance   | 0.8356309    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.96         |
# |    n_updates            | 810          |
# |    policy_gradient_loss | -0.00212     |
# |    value_loss           | 28.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 737          |
# |    ep_rew_mean          | 16           |
# | time/                   |              |
# |    fps                  | 456          |
# |    iterations           | 83           |
# |    time_elapsed         | 372          |
# |    total_timesteps      | 169984       |
# | train/                  |              |
# |    approx_kl            | 0.0071070693 |
# |    clip_fraction        | 0.0628       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.898       |
# |    explained_variance   | 0.7531978    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.55         |
# |    n_updates            | 820          |
# |    policy_gradient_loss | -0.00109     |
# |    value_loss           | 41.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 739          |
# |    ep_rew_mean          | 18           |
# | time/                   |              |
# |    fps                  | 456          |
# |    iterations           | 84           |
# |    time_elapsed         | 377          |
# |    total_timesteps      | 172032       |
# | train/                  |              |
# |    approx_kl            | 0.0024647275 |
# |    clip_fraction        | 0.0471       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.881       |
# |    explained_variance   | 0.6097086    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 115          |
# |    n_updates            | 830          |
# |    policy_gradient_loss | -0.00104     |
# |    value_loss           | 168          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 734          |
# |    ep_rew_mean          | 19.6         |
# | time/                   |              |
# |    fps                  | 456          |
# |    iterations           | 85           |
# |    time_elapsed         | 381          |
# |    total_timesteps      | 174080       |
# | train/                  |              |
# |    approx_kl            | 0.0041058697 |
# |    clip_fraction        | 0.0593       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.884       |
# |    explained_variance   | 0.61755884   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 93.7         |
# |    n_updates            | 840          |
# |    policy_gradient_loss | -0.00128     |
# |    value_loss           | 78.3         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 731         |
# |    ep_rew_mean          | 20.1        |
# | time/                   |             |
# |    fps                  | 456         |
# |    iterations           | 86          |
# |    time_elapsed         | 385         |
# |    total_timesteps      | 176128      |
# | train/                  |             |
# |    approx_kl            | 0.006206665 |
# |    clip_fraction        | 0.0597      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.917      |
# |    explained_variance   | 0.5794089   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.8        |
# |    n_updates            | 850         |
# |    policy_gradient_loss | -0.000437   |
# |    value_loss           | 36.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 733         |
# |    ep_rew_mean          | 19.9        |
# | time/                   |             |
# |    fps                  | 456         |
# |    iterations           | 87          |
# |    time_elapsed         | 390         |
# |    total_timesteps      | 178176      |
# | train/                  |             |
# |    approx_kl            | 0.012712551 |
# |    clip_fraction        | 0.0729      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.832      |
# |    explained_variance   | 0.7417261   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.83        |
# |    n_updates            | 860         |
# |    policy_gradient_loss | -0.00277    |
# |    value_loss           | 70.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 733         |
# |    ep_rew_mean          | 19.7        |
# | time/                   |             |
# |    fps                  | 456         |
# |    iterations           | 88          |
# |    time_elapsed         | 394         |
# |    total_timesteps      | 180224      |
# | train/                  |             |
# |    approx_kl            | 0.005607977 |
# |    clip_fraction        | 0.0786      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.824      |
# |    explained_variance   | 0.59274656  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 148         |
# |    n_updates            | 870         |
# |    policy_gradient_loss | -0.000978   |
# |    value_loss           | 62.7        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 732          |
# |    ep_rew_mean          | 19.7         |
# | time/                   |              |
# |    fps                  | 456          |
# |    iterations           | 89           |
# |    time_elapsed         | 399          |
# |    total_timesteps      | 182272       |
# | train/                  |              |
# |    approx_kl            | 0.0046144845 |
# |    clip_fraction        | 0.0455       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.711       |
# |    explained_variance   | 0.8489903    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.26         |
# |    n_updates            | 880          |
# |    policy_gradient_loss | -0.00168     |
# |    value_loss           | 16           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 736         |
# |    ep_rew_mean          | 20.6        |
# | time/                   |             |
# |    fps                  | 456         |
# |    iterations           | 90          |
# |    time_elapsed         | 403         |
# |    total_timesteps      | 184320      |
# | train/                  |             |
# |    approx_kl            | 0.004087816 |
# |    clip_fraction        | 0.0709      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.831      |
# |    explained_variance   | 0.81003946  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.01        |
# |    n_updates            | 890         |
# |    policy_gradient_loss | -0.00234    |
# |    value_loss           | 33.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 735         |
# |    ep_rew_mean          | 22          |
# | time/                   |             |
# |    fps                  | 456         |
# |    iterations           | 91          |
# |    time_elapsed         | 408         |
# |    total_timesteps      | 186368      |
# | train/                  |             |
# |    approx_kl            | 0.008418996 |
# |    clip_fraction        | 0.0941      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.893      |
# |    explained_variance   | 0.6088861   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.47        |
# |    n_updates            | 900         |
# |    policy_gradient_loss | -0.00406    |
# |    value_loss           | 24.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 733          |
# |    ep_rew_mean          | 20.4         |
# | time/                   |              |
# |    fps                  | 456          |
# |    iterations           | 92           |
# |    time_elapsed         | 412          |
# |    total_timesteps      | 188416       |
# | train/                  |              |
# |    approx_kl            | 0.0061119916 |
# |    clip_fraction        | 0.0713       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.893       |
# |    explained_variance   | 0.4941255    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 50.7         |
# |    n_updates            | 910          |
# |    policy_gradient_loss | -0.00209     |
# |    value_loss           | 96.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 728         |
# |    ep_rew_mean          | 19.2        |
# | time/                   |             |
# |    fps                  | 456         |
# |    iterations           | 93          |
# |    time_elapsed         | 417         |
# |    total_timesteps      | 190464      |
# | train/                  |             |
# |    approx_kl            | 0.008349489 |
# |    clip_fraction        | 0.0886      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.835      |
# |    explained_variance   | 0.51801157  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 49.3        |
# |    n_updates            | 920         |
# |    policy_gradient_loss | -0.00251    |
# |    value_loss           | 139         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 729         |
# |    ep_rew_mean          | 22.3        |
# | time/                   |             |
# |    fps                  | 456         |
# |    iterations           | 94          |
# |    time_elapsed         | 421         |
# |    total_timesteps      | 192512      |
# | train/                  |             |
# |    approx_kl            | 0.011796379 |
# |    clip_fraction        | 0.0551      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.924      |
# |    explained_variance   | 0.746935    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 31.4        |
# |    n_updates            | 930         |
# |    policy_gradient_loss | -0.00186    |
# |    value_loss           | 60.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 727          |
# |    ep_rew_mean          | 21.2         |
# | time/                   |              |
# |    fps                  | 456          |
# |    iterations           | 95           |
# |    time_elapsed         | 426          |
# |    total_timesteps      | 194560       |
# | train/                  |              |
# |    approx_kl            | 0.0056070667 |
# |    clip_fraction        | 0.035        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.805       |
# |    explained_variance   | 0.64159715   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 87           |
# |    n_updates            | 940          |
# |    policy_gradient_loss | -0.00145     |
# |    value_loss           | 87.8         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 725          |
# |    ep_rew_mean          | 20           |
# | time/                   |              |
# |    fps                  | 456          |
# |    iterations           | 96           |
# |    time_elapsed         | 430          |
# |    total_timesteps      | 196608       |
# | train/                  |              |
# |    approx_kl            | 0.0034434828 |
# |    clip_fraction        | 0.0284       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.869       |
# |    explained_variance   | 0.5485953    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.09         |
# |    n_updates            | 950          |
# |    policy_gradient_loss | -0.00106     |
# |    value_loss           | 94.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 729         |
# |    ep_rew_mean          | 19.8        |
# | time/                   |             |
# |    fps                  | 456         |
# |    iterations           | 97          |
# |    time_elapsed         | 435         |
# |    total_timesteps      | 198656      |
# | train/                  |             |
# |    approx_kl            | 0.011132993 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.888      |
# |    explained_variance   | 0.5220002   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 64.9        |
# |    n_updates            | 960         |
# |    policy_gradient_loss | -0.00504    |
# |    value_loss           | 42          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 732         |
# |    ep_rew_mean          | 20.1        |
# | time/                   |             |
# |    fps                  | 456         |
# |    iterations           | 98          |
# |    time_elapsed         | 439         |
# |    total_timesteps      | 200704      |
# | train/                  |             |
# |    approx_kl            | 0.008138853 |
# |    clip_fraction        | 0.0948      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.906      |
# |    explained_variance   | 0.65465987  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.78        |
# |    n_updates            | 970         |
# |    policy_gradient_loss | -0.00211    |
# |    value_loss           | 40.3        |
# -----------------------------------------

# %%
# solution
model = PPO(
    policy="MlpPolicy",
    env=env,
    n_steps=1024,
    batch_size=64,
    n_epochs=4,
    gamma=0.999,
    gae_lambda=0.98,
    ent_coef=0.01,
    verbose=1,
)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model_name = "ppo-LunarLander-v2"

# %%
model.learn(total_timesteps=1000000)
model_name = "LunarLander-v2"
model.save(model_name)
# Out:
# Streaming output truncated to the last 5000 lines.
# |    value_loss           | 101           |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 327         |
# |    ep_rew_mean          | 212         |
# | time/                   |             |
# |    fps                  | 564         |
# |    iterations           | 740         |
# |    time_elapsed         | 1341        |
# |    total_timesteps      | 757760      |
# | train/                  |             |
# |    approx_kl            | 0.004619845 |
# |    clip_fraction        | 0.0217      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.813      |
# |    explained_variance   | 0.9771421   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.43        |
# |    n_updates            | 2956        |
# |    policy_gradient_loss | -0.00182    |
# |    value_loss           | 17.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 327         |
# |    ep_rew_mean          | 212         |
# | time/                   |             |
# |    fps                  | 564         |
# |    iterations           | 741         |
# |    time_elapsed         | 1343        |
# |    total_timesteps      | 758784      |
# | train/                  |             |
# |    approx_kl            | 0.003874043 |
# |    clip_fraction        | 0.0503      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.754      |
# |    explained_variance   | 0.978047    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.6        |
# |    n_updates            | 2960        |
# |    policy_gradient_loss | -0.00274    |
# |    value_loss           | 23          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 323          |
# |    ep_rew_mean          | 209          |
# | time/                   |              |
# |    fps                  | 564          |
# |    iterations           | 742          |
# |    time_elapsed         | 1345         |
# |    total_timesteps      | 759808       |
# | train/                  |              |
# |    approx_kl            | 0.0007125568 |
# |    clip_fraction        | 0.000732     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.802       |
# |    explained_variance   | 0.59490246   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 544          |
# |    n_updates            | 2964         |
# |    policy_gradient_loss | -0.00112     |
# |    value_loss           | 903          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 321         |
# |    ep_rew_mean          | 209         |
# | time/                   |             |
# |    fps                  | 564         |
# |    iterations           | 743         |
# |    time_elapsed         | 1346        |
# |    total_timesteps      | 760832      |
# | train/                  |             |
# |    approx_kl            | 0.001020448 |
# |    clip_fraction        | 0.000488    |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.774      |
# |    explained_variance   | 0.8476824   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 331         |
# |    n_updates            | 2968        |
# |    policy_gradient_loss | -0.00181    |
# |    value_loss           | 499         |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 314           |
# |    ep_rew_mean          | 211           |
# | time/                   |               |
# |    fps                  | 564           |
# |    iterations           | 744           |
# |    time_elapsed         | 1348          |
# |    total_timesteps      | 761856        |
# | train/                  |               |
# |    approx_kl            | 9.8373974e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.757        |
# |    explained_variance   | 0.8558283     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 93.2          |
# |    n_updates            | 2972          |
# |    policy_gradient_loss | -0.000164     |
# |    value_loss           | 454           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 314           |
# |    ep_rew_mean          | 210           |
# | time/                   |               |
# |    fps                  | 564           |
# |    iterations           | 745           |
# |    time_elapsed         | 1350          |
# |    total_timesteps      | 762880        |
# | train/                  |               |
# |    approx_kl            | 0.00036420103 |
# |    clip_fraction        | 0.000488      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.777        |
# |    explained_variance   | 0.9040142     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 58.6          |
# |    n_updates            | 2976          |
# |    policy_gradient_loss | -0.000818     |
# |    value_loss           | 304           |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 313         |
# |    ep_rew_mean          | 212         |
# | time/                   |             |
# |    fps                  | 564         |
# |    iterations           | 746         |
# |    time_elapsed         | 1352        |
# |    total_timesteps      | 763904      |
# | train/                  |             |
# |    approx_kl            | 0.006960121 |
# |    clip_fraction        | 0.043       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.743      |
# |    explained_variance   | 0.63100016  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.1        |
# |    n_updates            | 2980        |
# |    policy_gradient_loss | -0.00737    |
# |    value_loss           | 713         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 312          |
# |    ep_rew_mean          | 211          |
# | time/                   |              |
# |    fps                  | 564          |
# |    iterations           | 747          |
# |    time_elapsed         | 1354         |
# |    total_timesteps      | 764928       |
# | train/                  |              |
# |    approx_kl            | 0.0013876185 |
# |    clip_fraction        | 0.0137       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.743       |
# |    explained_variance   | 0.9726111    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 12.5         |
# |    n_updates            | 2984         |
# |    policy_gradient_loss | -0.000783    |
# |    value_loss           | 34.3         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 313           |
# |    ep_rew_mean          | 213           |
# | time/                   |               |
# |    fps                  | 564           |
# |    iterations           | 748           |
# |    time_elapsed         | 1355          |
# |    total_timesteps      | 765952        |
# | train/                  |               |
# |    approx_kl            | 0.00074398646 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.714        |
# |    explained_variance   | 0.4162714     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 726           |
# |    n_updates            | 2988          |
# |    policy_gradient_loss | 0.000378      |
# |    value_loss           | 1.15e+03      |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 313         |
# |    ep_rew_mean          | 216         |
# | time/                   |             |
# |    fps                  | 564         |
# |    iterations           | 749         |
# |    time_elapsed         | 1357        |
# |    total_timesteps      | 766976      |
# | train/                  |             |
# |    approx_kl            | 0.006116543 |
# |    clip_fraction        | 0.0476      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.797      |
# |    explained_variance   | 0.97862595  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.27        |
# |    n_updates            | 2992        |
# |    policy_gradient_loss | -0.00401    |
# |    value_loss           | 19.5        |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 306           |
# |    ep_rew_mean          | 209           |
# | time/                   |               |
# |    fps                  | 564           |
# |    iterations           | 750           |
# |    time_elapsed         | 1359          |
# |    total_timesteps      | 768000        |
# | train/                  |               |
# |    approx_kl            | 0.00091930607 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.699        |
# |    explained_variance   | 0.65786755    |
# |    learning_rate        | 0.0003        |
# |    loss                 | 110           |
# |    n_updates            | 2996          |
# |    policy_gradient_loss | -0.000459     |
# |    value_loss           | 676           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 306          |
# |    ep_rew_mean          | 210          |
# | time/                   |              |
# |    fps                  | 564          |
# |    iterations           | 751          |
# |    time_elapsed         | 1361         |
# |    total_timesteps      | 769024       |
# | train/                  |              |
# |    approx_kl            | 1.651817e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.823       |
# |    explained_variance   | 0.856763     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 118          |
# |    n_updates            | 3000         |
# |    policy_gradient_loss | -0.000124    |
# |    value_loss           | 890          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 305         |
# |    ep_rew_mean          | 206         |
# | time/                   |             |
# |    fps                  | 564         |
# |    iterations           | 752         |
# |    time_elapsed         | 1363        |
# |    total_timesteps      | 770048      |
# | train/                  |             |
# |    approx_kl            | 0.028943805 |
# |    clip_fraction        | 0.227       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.628      |
# |    explained_variance   | 0.9742638   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.36        |
# |    n_updates            | 3004        |
# |    policy_gradient_loss | -0.00273    |
# |    value_loss           | 23.6        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 303        |
# |    ep_rew_mean          | 204        |
# | time/                   |            |
# |    fps                  | 564        |
# |    iterations           | 753        |
# |    time_elapsed         | 1365       |
# |    total_timesteps      | 771072     |
# | train/                  |            |
# |    approx_kl            | 0.00731651 |
# |    clip_fraction        | 0.0354     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.736     |
# |    explained_variance   | 0.87897503 |
# |    learning_rate        | 0.0003     |
# |    loss                 | 85.4       |
# |    n_updates            | 3008       |
# |    policy_gradient_loss | 0.00149    |
# |    value_loss           | 298        |
# ----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 300           |
# |    ep_rew_mean          | 206           |
# | time/                   |               |
# |    fps                  | 564           |
# |    iterations           | 754           |
# |    time_elapsed         | 1366          |
# |    total_timesteps      | 772096        |
# | train/                  |               |
# |    approx_kl            | 0.00016095198 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.824        |
# |    explained_variance   | 0.7200887     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 259           |
# |    n_updates            | 3012          |
# |    policy_gradient_loss | -0.000144     |
# |    value_loss           | 1.01e+03      |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 302         |
# |    ep_rew_mean          | 207         |
# | time/                   |             |
# |    fps                  | 564         |
# |    iterations           | 755         |
# |    time_elapsed         | 1368        |
# |    total_timesteps      | 773120      |
# | train/                  |             |
# |    approx_kl            | 0.006154334 |
# |    clip_fraction        | 0.0269      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.762      |
# |    explained_variance   | 0.95361453  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.4        |
# |    n_updates            | 3016        |
# |    policy_gradient_loss | -0.00119    |
# |    value_loss           | 36.5        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 302          |
# |    ep_rew_mean          | 210          |
# | time/                   |              |
# |    fps                  | 564          |
# |    iterations           | 756          |
# |    time_elapsed         | 1370         |
# |    total_timesteps      | 774144       |
# | train/                  |              |
# |    approx_kl            | 0.0067273667 |
# |    clip_fraction        | 0.0496       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.729       |
# |    explained_variance   | 0.977125     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.72         |
# |    n_updates            | 3020         |
# |    policy_gradient_loss | -0.00329     |
# |    value_loss           | 27.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 302          |
# |    ep_rew_mean          | 211          |
# | time/                   |              |
# |    fps                  | 564          |
# |    iterations           | 757          |
# |    time_elapsed         | 1372         |
# |    total_timesteps      | 775168       |
# | train/                  |              |
# |    approx_kl            | 0.0023998083 |
# |    clip_fraction        | 0.0217       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.803       |
# |    explained_variance   | 0.9729797    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.8          |
# |    n_updates            | 3024         |
# |    policy_gradient_loss | -0.00102     |
# |    value_loss           | 16.8         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 301          |
# |    ep_rew_mean          | 209          |
# | time/                   |              |
# |    fps                  | 564          |
# |    iterations           | 758          |
# |    time_elapsed         | 1374         |
# |    total_timesteps      | 776192       |
# | train/                  |              |
# |    approx_kl            | 0.0032750785 |
# |    clip_fraction        | 0.0571       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.743       |
# |    explained_variance   | 0.8298806    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 43.2         |
# |    n_updates            | 3028         |
# |    policy_gradient_loss | 0.000768     |
# |    value_loss           | 159          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 310          |
# |    ep_rew_mean          | 212          |
# | time/                   |              |
# |    fps                  | 564          |
# |    iterations           | 759          |
# |    time_elapsed         | 1375         |
# |    total_timesteps      | 777216       |
# | train/                  |              |
# |    approx_kl            | 0.0005002025 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.72        |
# |    explained_variance   | 0.7736957    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 273          |
# |    n_updates            | 3032         |
# |    policy_gradient_loss | -0.000565    |
# |    value_loss           | 382          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 309         |
# |    ep_rew_mean          | 213         |
# | time/                   |             |
# |    fps                  | 564         |
# |    iterations           | 760         |
# |    time_elapsed         | 1377        |
# |    total_timesteps      | 778240      |
# | train/                  |             |
# |    approx_kl            | 0.004751293 |
# |    clip_fraction        | 0.0398      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.806      |
# |    explained_variance   | 0.9896463   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.2         |
# |    n_updates            | 3036        |
# |    policy_gradient_loss | -0.00162    |
# |    value_loss           | 10.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 311          |
# |    ep_rew_mean          | 215          |
# | time/                   |              |
# |    fps                  | 564          |
# |    iterations           | 761          |
# |    time_elapsed         | 1379         |
# |    total_timesteps      | 779264       |
# | train/                  |              |
# |    approx_kl            | 0.0037957178 |
# |    clip_fraction        | 0.0117       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.731       |
# |    explained_variance   | 0.6479932    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 106          |
# |    n_updates            | 3040         |
# |    policy_gradient_loss | -7.33e-05    |
# |    value_loss           | 375          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 313          |
# |    ep_rew_mean          | 218          |
# | time/                   |              |
# |    fps                  | 564          |
# |    iterations           | 762          |
# |    time_elapsed         | 1381         |
# |    total_timesteps      | 780288       |
# | train/                  |              |
# |    approx_kl            | 0.0010585438 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.7         |
# |    explained_variance   | 0.4175297    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 842          |
# |    n_updates            | 3044         |
# |    policy_gradient_loss | -0.00139     |
# |    value_loss           | 1.08e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 314          |
# |    ep_rew_mean          | 220          |
# | time/                   |              |
# |    fps                  | 564          |
# |    iterations           | 763          |
# |    time_elapsed         | 1382         |
# |    total_timesteps      | 781312       |
# | train/                  |              |
# |    approx_kl            | 0.0007808888 |
# |    clip_fraction        | 0.00146      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.748       |
# |    explained_variance   | 0.8506524    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.68         |
# |    n_updates            | 3048         |
# |    policy_gradient_loss | 0.000394     |
# |    value_loss           | 65.8         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 315           |
# |    ep_rew_mean          | 219           |
# | time/                   |               |
# |    fps                  | 564           |
# |    iterations           | 764           |
# |    time_elapsed         | 1384          |
# |    total_timesteps      | 782336        |
# | train/                  |               |
# |    approx_kl            | 0.00079499517 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.788        |
# |    explained_variance   | 0.57254857    |
# |    learning_rate        | 0.0003        |
# |    loss                 | 439           |
# |    n_updates            | 3052          |
# |    policy_gradient_loss | 0.000202      |
# |    value_loss           | 901           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 316          |
# |    ep_rew_mean          | 219          |
# | time/                   |              |
# |    fps                  | 564          |
# |    iterations           | 765          |
# |    time_elapsed         | 1386         |
# |    total_timesteps      | 783360       |
# | train/                  |              |
# |    approx_kl            | 0.0003835627 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.867       |
# |    explained_variance   | 0.6489513    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 327          |
# |    n_updates            | 3056         |
# |    policy_gradient_loss | -0.000173    |
# |    value_loss           | 963          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 315          |
# |    ep_rew_mean          | 221          |
# | time/                   |              |
# |    fps                  | 564          |
# |    iterations           | 766          |
# |    time_elapsed         | 1388         |
# |    total_timesteps      | 784384       |
# | train/                  |              |
# |    approx_kl            | 0.0028495623 |
# |    clip_fraction        | 0.0122       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.743       |
# |    explained_variance   | 0.92290974   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 12.2         |
# |    n_updates            | 3060         |
# |    policy_gradient_loss | -0.000954    |
# |    value_loss           | 47.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 315          |
# |    ep_rew_mean          | 221          |
# | time/                   |              |
# |    fps                  | 564          |
# |    iterations           | 767          |
# |    time_elapsed         | 1390         |
# |    total_timesteps      | 785408       |
# | train/                  |              |
# |    approx_kl            | 0.0019072434 |
# |    clip_fraction        | 0.00293      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.746       |
# |    explained_variance   | 0.97021824   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 10.9         |
# |    n_updates            | 3064         |
# |    policy_gradient_loss | 0.000682     |
# |    value_loss           | 26.6         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 324          |
# |    ep_rew_mean          | 220          |
# | time/                   |              |
# |    fps                  | 564          |
# |    iterations           | 768          |
# |    time_elapsed         | 1392         |
# |    total_timesteps      | 786432       |
# | train/                  |              |
# |    approx_kl            | 0.0025488618 |
# |    clip_fraction        | 0.0249       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.764       |
# |    explained_variance   | 0.9488009    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 10.4         |
# |    n_updates            | 3068         |
# |    policy_gradient_loss | -0.00122     |
# |    value_loss           | 33.1         |
# ------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 321       |
# |    ep_rew_mean          | 220       |
# | time/                   |           |
# |    fps                  | 564       |
# |    iterations           | 769       |
# |    time_elapsed         | 1393      |
# |    total_timesteps      | 787456    |
# | train/                  |           |
# |    approx_kl            | 0.0393624 |
# |    clip_fraction        | 0.071     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.54     |
# |    explained_variance   | 0.9691029 |
# |    learning_rate        | 0.0003    |
# |    loss                 | 3.31      |
# |    n_updates            | 3072      |
# |    policy_gradient_loss | -0.00533  |
# |    value_loss           | 15.5      |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 321         |
# |    ep_rew_mean          | 219         |
# | time/                   |             |
# |    fps                  | 564         |
# |    iterations           | 770         |
# |    time_elapsed         | 1395        |
# |    total_timesteps      | 788480      |
# | train/                  |             |
# |    approx_kl            | 0.004655611 |
# |    clip_fraction        | 0.0486      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.76       |
# |    explained_variance   | 0.9647206   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.7        |
# |    n_updates            | 3076        |
# |    policy_gradient_loss | -0.00203    |
# |    value_loss           | 29.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 321         |
# |    ep_rew_mean          | 219         |
# | time/                   |             |
# |    fps                  | 564         |
# |    iterations           | 771         |
# |    time_elapsed         | 1397        |
# |    total_timesteps      | 789504      |
# | train/                  |             |
# |    approx_kl            | 0.005678674 |
# |    clip_fraction        | 0.052       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.755      |
# |    explained_variance   | 0.99056196  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.9         |
# |    n_updates            | 3080        |
# |    policy_gradient_loss | -0.00179    |
# |    value_loss           | 7.97        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 320          |
# |    ep_rew_mean          | 218          |
# | time/                   |              |
# |    fps                  | 564          |
# |    iterations           | 772          |
# |    time_elapsed         | 1399         |
# |    total_timesteps      | 790528       |
# | train/                  |              |
# |    approx_kl            | 0.0033538376 |
# |    clip_fraction        | 0.0244       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.822       |
# |    explained_variance   | 0.9847022    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.52         |
# |    n_updates            | 3084         |
# |    policy_gradient_loss | -0.00319     |
# |    value_loss           | 14.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 322          |
# |    ep_rew_mean          | 223          |
# | time/                   |              |
# |    fps                  | 564          |
# |    iterations           | 773          |
# |    time_elapsed         | 1401         |
# |    total_timesteps      | 791552       |
# | train/                  |              |
# |    approx_kl            | 0.0029090275 |
# |    clip_fraction        | 0.012        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.716       |
# |    explained_variance   | 0.97167045   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 10.7         |
# |    n_updates            | 3088         |
# |    policy_gradient_loss | -0.00318     |
# |    value_loss           | 30.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 322          |
# |    ep_rew_mean          | 224          |
# | time/                   |              |
# |    fps                  | 564          |
# |    iterations           | 774          |
# |    time_elapsed         | 1402         |
# |    total_timesteps      | 792576       |
# | train/                  |              |
# |    approx_kl            | 0.0045501236 |
# |    clip_fraction        | 0.0232       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.784       |
# |    explained_variance   | 0.9818098    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.21         |
# |    n_updates            | 3092         |
# |    policy_gradient_loss | -0.00302     |
# |    value_loss           | 22.2         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 323         |
# |    ep_rew_mean          | 225         |
# | time/                   |             |
# |    fps                  | 564         |
# |    iterations           | 775         |
# |    time_elapsed         | 1404        |
# |    total_timesteps      | 793600      |
# | train/                  |             |
# |    approx_kl            | 0.006983702 |
# |    clip_fraction        | 0.0437      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.756      |
# |    explained_variance   | 0.9770567   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.7        |
# |    n_updates            | 3096        |
# |    policy_gradient_loss | -0.000105   |
# |    value_loss           | 27.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 322          |
# |    ep_rew_mean          | 224          |
# | time/                   |              |
# |    fps                  | 564          |
# |    iterations           | 776          |
# |    time_elapsed         | 1406         |
# |    total_timesteps      | 794624       |
# | train/                  |              |
# |    approx_kl            | 0.0030123238 |
# |    clip_fraction        | 0.0222       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.765       |
# |    explained_variance   | 0.98048466   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.65         |
# |    n_updates            | 3100         |
# |    policy_gradient_loss | -0.00454     |
# |    value_loss           | 19.1         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 322         |
# |    ep_rew_mean          | 221         |
# | time/                   |             |
# |    fps                  | 564         |
# |    iterations           | 777         |
# |    time_elapsed         | 1408        |
# |    total_timesteps      | 795648      |
# | train/                  |             |
# |    approx_kl            | 0.006968857 |
# |    clip_fraction        | 0.073       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.782      |
# |    explained_variance   | 0.5620036   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 758         |
# |    n_updates            | 3104        |
# |    policy_gradient_loss | -0.00197    |
# |    value_loss           | 1.94e+03    |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 322           |
# |    ep_rew_mean          | 221           |
# | time/                   |               |
# |    fps                  | 564           |
# |    iterations           | 778           |
# |    time_elapsed         | 1410          |
# |    total_timesteps      | 796672        |
# | train/                  |               |
# |    approx_kl            | 0.00011888327 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.694        |
# |    explained_variance   | 0.8809652     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 96            |
# |    n_updates            | 3108          |
# |    policy_gradient_loss | -0.000327     |
# |    value_loss           | 366           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 322          |
# |    ep_rew_mean          | 221          |
# | time/                   |              |
# |    fps                  | 564          |
# |    iterations           | 779          |
# |    time_elapsed         | 1411         |
# |    total_timesteps      | 797696       |
# | train/                  |              |
# |    approx_kl            | 0.0036338933 |
# |    clip_fraction        | 0.0286       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.764       |
# |    explained_variance   | 0.9756839    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.64         |
# |    n_updates            | 3112         |
# |    policy_gradient_loss | -0.0043      |
# |    value_loss           | 20.5         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 329           |
# |    ep_rew_mean          | 220           |
# | time/                   |               |
# |    fps                  | 564           |
# |    iterations           | 780           |
# |    time_elapsed         | 1413          |
# |    total_timesteps      | 798720        |
# | train/                  |               |
# |    approx_kl            | 0.00036461506 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.651        |
# |    explained_variance   | 0.9171981     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 85.9          |
# |    n_updates            | 3116          |
# |    policy_gradient_loss | -0.000105     |
# |    value_loss           | 249           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 328          |
# |    ep_rew_mean          | 222          |
# | time/                   |              |
# |    fps                  | 564          |
# |    iterations           | 781          |
# |    time_elapsed         | 1415         |
# |    total_timesteps      | 799744       |
# | train/                  |              |
# |    approx_kl            | 0.0011386673 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.705       |
# |    explained_variance   | 0.9554498    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 34.9         |
# |    n_updates            | 3120         |
# |    policy_gradient_loss | -0.00114     |
# |    value_loss           | 195          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 333           |
# |    ep_rew_mean          | 226           |
# | time/                   |               |
# |    fps                  | 564           |
# |    iterations           | 782           |
# |    time_elapsed         | 1417          |
# |    total_timesteps      | 800768        |
# | train/                  |               |
# |    approx_kl            | 0.00041327073 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.826        |
# |    explained_variance   | 0.8711009     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 11.5          |
# |    n_updates            | 3124          |
# |    policy_gradient_loss | -0.000219     |
# |    value_loss           | 91.1          |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 326         |
# |    ep_rew_mean          | 228         |
# | time/                   |             |
# |    fps                  | 564         |
# |    iterations           | 783         |
# |    time_elapsed         | 1419        |
# |    total_timesteps      | 801792      |
# | train/                  |             |
# |    approx_kl            | 0.007398372 |
# |    clip_fraction        | 0.0598      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.67       |
# |    explained_variance   | 0.99066925  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.67        |
# |    n_updates            | 3128        |
# |    policy_gradient_loss | -0.000104   |
# |    value_loss           | 8.25        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 327          |
# |    ep_rew_mean          | 231          |
# | time/                   |              |
# |    fps                  | 564          |
# |    iterations           | 784          |
# |    time_elapsed         | 1420         |
# |    total_timesteps      | 802816       |
# | train/                  |              |
# |    approx_kl            | 0.0013323242 |
# |    clip_fraction        | 0.00708      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.693       |
# |    explained_variance   | 0.8452504    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 57.1         |
# |    n_updates            | 3132         |
# |    policy_gradient_loss | -0.00178     |
# |    value_loss           | 393          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 328         |
# |    ep_rew_mean          | 235         |
# | time/                   |             |
# |    fps                  | 565         |
# |    iterations           | 785         |
# |    time_elapsed         | 1422        |
# |    total_timesteps      | 803840      |
# | train/                  |             |
# |    approx_kl            | 0.002224048 |
# |    clip_fraction        | 0.00342     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.735      |
# |    explained_variance   | 0.8623356   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.88        |
# |    n_updates            | 3136        |
# |    policy_gradient_loss | -0.00146    |
# |    value_loss           | 77.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 326          |
# |    ep_rew_mean          | 228          |
# | time/                   |              |
# |    fps                  | 565          |
# |    iterations           | 786          |
# |    time_elapsed         | 1424         |
# |    total_timesteps      | 804864       |
# | train/                  |              |
# |    approx_kl            | 0.0045729005 |
# |    clip_fraction        | 0.0366       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.739       |
# |    explained_variance   | 0.98778063   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.23         |
# |    n_updates            | 3140         |
# |    policy_gradient_loss | -0.00332     |
# |    value_loss           | 14.3         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 325         |
# |    ep_rew_mean          | 228         |
# | time/                   |             |
# |    fps                  | 565         |
# |    iterations           | 787         |
# |    time_elapsed         | 1426        |
# |    total_timesteps      | 805888      |
# | train/                  |             |
# |    approx_kl            | 0.004704985 |
# |    clip_fraction        | 0.033       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.839      |
# |    explained_variance   | 0.6241045   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 917         |
# |    n_updates            | 3144        |
# |    policy_gradient_loss | -0.00177    |
# |    value_loss           | 2.4e+03     |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 325           |
# |    ep_rew_mean          | 224           |
# | time/                   |               |
# |    fps                  | 564           |
# |    iterations           | 788           |
# |    time_elapsed         | 1428          |
# |    total_timesteps      | 806912        |
# | train/                  |               |
# |    approx_kl            | 0.00028062682 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.621        |
# |    explained_variance   | 0.8975064     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 20.4          |
# |    n_updates            | 3148          |
# |    policy_gradient_loss | -0.000296     |
# |    value_loss           | 149           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 327           |
# |    ep_rew_mean          | 227           |
# | time/                   |               |
# |    fps                  | 564           |
# |    iterations           | 789           |
# |    time_elapsed         | 1429          |
# |    total_timesteps      | 807936        |
# | train/                  |               |
# |    approx_kl            | 2.1680433e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.734        |
# |    explained_variance   | 0.81260467    |
# |    learning_rate        | 0.0003        |
# |    loss                 | 276           |
# |    n_updates            | 3152          |
# |    policy_gradient_loss | -0.000101     |
# |    value_loss           | 677           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 320          |
# |    ep_rew_mean          | 228          |
# | time/                   |              |
# |    fps                  | 564          |
# |    iterations           | 790          |
# |    time_elapsed         | 1431         |
# |    total_timesteps      | 808960       |
# | train/                  |              |
# |    approx_kl            | 0.0046388838 |
# |    clip_fraction        | 0.0261       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.79        |
# |    explained_variance   | 0.97930944   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.05         |
# |    n_updates            | 3156         |
# |    policy_gradient_loss | -0.00222     |
# |    value_loss           | 19.6         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 319          |
# |    ep_rew_mean          | 227          |
# | time/                   |              |
# |    fps                  | 564          |
# |    iterations           | 791          |
# |    time_elapsed         | 1433         |
# |    total_timesteps      | 809984       |
# | train/                  |              |
# |    approx_kl            | 0.0029858113 |
# |    clip_fraction        | 0.0278       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.766       |
# |    explained_variance   | 0.9857437    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.84         |
# |    n_updates            | 3160         |
# |    policy_gradient_loss | -0.00379     |
# |    value_loss           | 11.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 324          |
# |    ep_rew_mean          | 227          |
# | time/                   |              |
# |    fps                  | 564          |
# |    iterations           | 792          |
# |    time_elapsed         | 1435         |
# |    total_timesteps      | 811008       |
# | train/                  |              |
# |    approx_kl            | 0.0036039192 |
# |    clip_fraction        | 0.0203       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.748       |
# |    explained_variance   | 0.9826493    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.28         |
# |    n_updates            | 3164         |
# |    policy_gradient_loss | -0.00179     |
# |    value_loss           | 14.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 324          |
# |    ep_rew_mean          | 224          |
# ...
# |    ep_len_mean          | 316          |
# |    ep_rew_mean          | 232          |
# | time/                   |              |
# |    fps                  | 565          |
# |    iterations           | 960          |
# |    time_elapsed         | 1739         |
# |    total_timesteps      | 983040       |
# | train/                  |              |
# |    approx_kl            | 0.0004071872 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.669       |
# |    explained_variance   | 0.92046857   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.23         |
# |    n_updates            | 3836         |
# |    policy_gradient_loss | -9.9e-05     |
# |    value_loss           | 71.8         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 316           |
# |    ep_rew_mean          | 231           |
# | time/                   |               |
# |    fps                  | 565           |
# |    iterations           | 961           |
# |    time_elapsed         | 1741          |
# |    total_timesteps      | 984064        |
# | train/                  |               |
# |    approx_kl            | 0.00018033484 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.817        |
# |    explained_variance   | 0.57858       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 687           |
# |    n_updates            | 3840          |
# |    policy_gradient_loss | 0.00036       |
# |    value_loss           | 1.8e+03       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 309           |
# |    ep_rew_mean          | 231           |
# | time/                   |               |
# |    fps                  | 565           |
# |    iterations           | 962           |
# |    time_elapsed         | 1743          |
# |    total_timesteps      | 985088        |
# | train/                  |               |
# |    approx_kl            | 0.00037600478 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.641        |
# |    explained_variance   | 0.7359991     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 141           |
# |    n_updates            | 3844          |
# |    policy_gradient_loss | -0.000741     |
# |    value_loss           | 736           |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 307         |
# |    ep_rew_mean          | 230         |
# | time/                   |             |
# |    fps                  | 565         |
# |    iterations           | 963         |
# |    time_elapsed         | 1744        |
# |    total_timesteps      | 986112      |
# | train/                  |             |
# |    approx_kl            | 0.006891667 |
# |    clip_fraction        | 0.0486      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.765      |
# |    explained_variance   | 0.9609311   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.38        |
# |    n_updates            | 3848        |
# |    policy_gradient_loss | -0.00511    |
# |    value_loss           | 29.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 306          |
# |    ep_rew_mean          | 232          |
# | time/                   |              |
# |    fps                  | 565          |
# |    iterations           | 964          |
# |    time_elapsed         | 1746         |
# |    total_timesteps      | 987136       |
# | train/                  |              |
# |    approx_kl            | 0.0018637197 |
# |    clip_fraction        | 0.00171      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.74        |
# |    explained_variance   | 0.6793219    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 565          |
# |    n_updates            | 3852         |
# |    policy_gradient_loss | -0.00112     |
# |    value_loss           | 794          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 306          |
# |    ep_rew_mean          | 230          |
# | time/                   |              |
# |    fps                  | 565          |
# |    iterations           | 965          |
# |    time_elapsed         | 1748         |
# |    total_timesteps      | 988160       |
# | train/                  |              |
# |    approx_kl            | 0.0020325384 |
# |    clip_fraction        | 0.012        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.633       |
# |    explained_variance   | 0.9767509    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.17         |
# |    n_updates            | 3856         |
# |    policy_gradient_loss | -0.00261     |
# |    value_loss           | 23.2         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 298         |
# |    ep_rew_mean          | 229         |
# | time/                   |             |
# |    fps                  | 565         |
# |    iterations           | 966         |
# |    time_elapsed         | 1750        |
# |    total_timesteps      | 989184      |
# | train/                  |             |
# |    approx_kl            | 0.014175374 |
# |    clip_fraction        | 0.181       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.691      |
# |    explained_variance   | 0.5809493   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 707         |
# |    n_updates            | 3860        |
# |    policy_gradient_loss | 0.00205     |
# |    value_loss           | 1.7e+03     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 297          |
# |    ep_rew_mean          | 232          |
# | time/                   |              |
# |    fps                  | 565          |
# |    iterations           | 967          |
# |    time_elapsed         | 1752         |
# |    total_timesteps      | 990208       |
# | train/                  |              |
# |    approx_kl            | 0.0042122267 |
# |    clip_fraction        | 0.011        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.835       |
# |    explained_variance   | 0.63891697   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 124          |
# |    n_updates            | 3864         |
# |    policy_gradient_loss | -0.00175     |
# |    value_loss           | 745          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 297        |
# |    ep_rew_mean          | 230        |
# | time/                   |            |
# |    fps                  | 565        |
# |    iterations           | 968        |
# |    time_elapsed         | 1754       |
# |    total_timesteps      | 991232     |
# | train/                  |            |
# |    approx_kl            | 0.00077839 |
# |    clip_fraction        | 0.00293    |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.666     |
# |    explained_variance   | 0.860492   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 29.4       |
# |    n_updates            | 3868       |
# |    policy_gradient_loss | -0.000502  |
# |    value_loss           | 176        |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 298          |
# |    ep_rew_mean          | 232          |
# | time/                   |              |
# |    fps                  | 565          |
# |    iterations           | 969          |
# |    time_elapsed         | 1755         |
# |    total_timesteps      | 992256       |
# | train/                  |              |
# |    approx_kl            | 0.0003960458 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.79        |
# |    explained_variance   | 0.70970184   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 419          |
# |    n_updates            | 3872         |
# |    policy_gradient_loss | -0.000401    |
# |    value_loss           | 1.05e+03     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 305        |
# |    ep_rew_mean          | 232        |
# | time/                   |            |
# |    fps                  | 565        |
# |    iterations           | 970        |
# |    time_elapsed         | 1757       |
# |    total_timesteps      | 993280     |
# | train/                  |            |
# |    approx_kl            | 0.00329451 |
# |    clip_fraction        | 0.00439    |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.707     |
# |    explained_variance   | 0.9405704  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 61.5       |
# |    n_updates            | 3876       |
# |    policy_gradient_loss | -0.00158   |
# |    value_loss           | 168        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 306         |
# |    ep_rew_mean          | 232         |
# | time/                   |             |
# |    fps                  | 565         |
# |    iterations           | 971         |
# |    time_elapsed         | 1759        |
# |    total_timesteps      | 994304      |
# | train/                  |             |
# |    approx_kl            | 0.006220768 |
# |    clip_fraction        | 0.00171     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.662      |
# |    explained_variance   | 0.9622055   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 34          |
# |    n_updates            | 3880        |
# |    policy_gradient_loss | -0.00288    |
# |    value_loss           | 152         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 306          |
# |    ep_rew_mean          | 232          |
# | time/                   |              |
# |    fps                  | 565          |
# |    iterations           | 972          |
# |    time_elapsed         | 1761         |
# |    total_timesteps      | 995328       |
# | train/                  |              |
# |    approx_kl            | 0.0025082068 |
# |    clip_fraction        | 0.00806      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.711       |
# |    explained_variance   | 0.8638787    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 45.8         |
# |    n_updates            | 3884         |
# |    policy_gradient_loss | -0.0018      |
# |    value_loss           | 114          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 307          |
# |    ep_rew_mean          | 234          |
# | time/                   |              |
# |    fps                  | 565          |
# |    iterations           | 973          |
# |    time_elapsed         | 1763         |
# |    total_timesteps      | 996352       |
# | train/                  |              |
# |    approx_kl            | 0.0035691203 |
# |    clip_fraction        | 0.0195       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.697       |
# |    explained_variance   | 0.9677046    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 10.3         |
# |    n_updates            | 3888         |
# |    policy_gradient_loss | -0.00112     |
# |    value_loss           | 37.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 305          |
# |    ep_rew_mean          | 233          |
# | time/                   |              |
# |    fps                  | 565          |
# |    iterations           | 974          |
# |    time_elapsed         | 1764         |
# |    total_timesteps      | 997376       |
# | train/                  |              |
# |    approx_kl            | 0.0040013976 |
# |    clip_fraction        | 0.0103       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.647       |
# |    explained_variance   | 0.9591066    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.88         |
# |    n_updates            | 3892         |
# |    policy_gradient_loss | -0.00126     |
# |    value_loss           | 29.3         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 304         |
# |    ep_rew_mean          | 233         |
# | time/                   |             |
# |    fps                  | 565         |
# |    iterations           | 975         |
# |    time_elapsed         | 1766        |
# |    total_timesteps      | 998400      |
# | train/                  |             |
# |    approx_kl            | 0.004844804 |
# |    clip_fraction        | 0.0403      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.756      |
# |    explained_variance   | 0.98534906  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.9         |
# |    n_updates            | 3896        |
# |    policy_gradient_loss | -0.000632   |
# |    value_loss           | 13.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 305         |
# |    ep_rew_mean          | 234         |
# | time/                   |             |
# |    fps                  | 565         |
# |    iterations           | 976         |
# |    time_elapsed         | 1768        |
# |    total_timesteps      | 999424      |
# | train/                  |             |
# |    approx_kl            | 0.001755691 |
# |    clip_fraction        | 0.00977     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.687      |
# |    explained_variance   | 0.70651186  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 317         |
# |    n_updates            | 3900        |
# |    policy_gradient_loss | 0.000101    |
# |    value_loss           | 631         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 305         |
# |    ep_rew_mean          | 234         |
# | time/                   |             |
# |    fps                  | 565         |
# |    iterations           | 977         |
# |    time_elapsed         | 1770        |
# |    total_timesteps      | 1000448     |
# | train/                  |             |
# |    approx_kl            | 0.003697534 |
# |    clip_fraction        | 0.0256      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.645      |
# |    explained_variance   | 0.98913294  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.43        |
# |    n_updates            | 3904        |
# |    policy_gradient_loss | -0.000369   |
# |    value_loss           | 15.4        |
# -----------------------------------------

# %%
# creating an environment for evaluation
from stable_baselines3.common.evaluation import evaluate_policy

eval_env = gym.make("LunarLander-v2")

mean_reward, std_reward = evaluate_policy(
    model,
    eval_env,
    n_eval_episodes=10,
    render=False
)
print(f"Mean reward: {mean_reward}, Std reward: {std_reward}")
# Out:
# /usr/local/lib/python3.11/dist-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Mean reward: 259.09728928954365, Std reward: 48.226560589289626
